# %% [markdown]
# $  % These are latex commands (i.e., macros).
#    \newcommand{\vec}[1]{ \boldsymbol{\mathbf{#1}} }
#    \newcommand{\R}{\mathbb{R}}
#    \newcommand{\C}{\mathbb{C}}
# $
#
# ## THIS IS A TEST
#
# We have latex new commands at the top of this cell -- namely __\vec__ and __\R__ and __\C__
#
# If I execute this cell and then those below, everything works.
#
# BUT TWO ISSUES:
# 1. When I load the notebook, the first few cells do not render using the __\newcommands__ defined at the top of this cell
# 2. I can't get __nbconvert__ to use the __newcommand__ definitions either

# %%
import numpy as np ##  Now we do some Python

# %% [markdown]
# I have used a newcommand to redefine __\vec__ so that A vector now renders in bold (no "arrow over letter").
#
# Here is what this looks like in this cell: $\vec{v}$
#
# I also have a __newcommand__ that defines __\R__ to be the math black-board bold double struck R:
#
# It renders as follows: $\R$
#
# TO GET THIS CELL TO RENDER, I MUST PUT A SPACE OR MAKE OTHER MOD AND THEN EXECUTE.

# %%
A = np.random.rand(2,2)
A
# Out:
# array([[0.78185794, 0.95781878],
#        [0.47493509, 0.29464465]])

# %% [markdown]
# Now more markdown: Here I just repeat the above:
#
# I have used a newcommand to redefine __\vec__ so that A vector now renders in bold (no "arrow over letter").
#
# Here is what this looks like in this cell: $\vec{v}$
#
# I also have a __newcommand__ that defines __\R__ to be the math black-board bold double struck R:
#
# It renders as follows: $\R$

# %%
A.trace()
# Out:
# np.float64(1.0765025904608754)

# %% [markdown]
# Again: I have used a newcommand to redefine __\vec__ so that A vector now renders in bold (no "arrow over letter").
#
# Here is what this looks like in this cell: $\vec{v}$
#
# I also have a __newcommand__ that defines __\R__ to be the math black-board bold double struck R:
#
# It renders as follows: $\R$

# %%
A @ A.T
# Out:
# array([[1.52871865, 0.65354795],
#        [0.65354795, 0.31237881]])

# %% [markdown]
# Again: I have used a newcommand to redefine __\vec__ so that A vector now renders in bold (no "arrow over letter").
#
# Here is what this looks like in this cell: $\vec{v}$
#
# I also have a __newcommand__ that defines __\R__ to be the math black-board bold double struck R:
#
# It renders as follows: $\R$

# %%
np.linalg.det(A)
# Out:
# np.float64(-0.22453148697258585)

# %% [markdown]
# Again: I have used a newcommand to redefine __\vec__ so that A vector now renders in bold (no "arrow over letter").
#
# Here is what this looks like in this cell: $\vec{v}$
#
# I also have a __newcommand__ that defines __\R__ to be the math black-board bold double struck R:
#
# It renders as follows: $\R$

# %%
np.linalg.norm(A)
# Out:
# np.float64(1.3568704659129924)

# %% [markdown]
# Again: I have used a newcommand to redefine __\vec__ so that A vector now renders in bold (no "arrow over letter").
#
# Here is what this looks like in this cell: $\vec{v}$
#
# I also have a __newcommand__ that defines __\R__ to be the math black-board bold double struck R:
#
# It renders as follows: $\R$

# %%
np.linalg.norm(A,1)
# Out:
# np.float64(1.2567930252679376)

# %% [markdown]
# Again: I have used a newcommand to redefine __\vec__ so that A vector now renders in bold (no "arrow over letter").
#
# Here is what this looks like in this cell: $\vec{v}$
#
# I also have a __newcommand__ that defines __\R__ to be the math black-board bold double struck R:
#
# It renders as follows: $\R$

# %%
np.linalg.norm(A,'fro')
# Out:
# np.float64(1.3568704659129924)

# %% [markdown]
# Again: I have used a newcommand to redefine __\vec__ so that A vector now renders in bold (no "arrow over letter").
#
# Here is what this looks like in this cell: $\vec{v}$
#
# I also have a __newcommand__ that defines __\R__ to be the math black-board bold double struck R:
#
# It renders as follows: $\R$

# %%
np.linalg.norm(A.T @ A, 2)
# Out:
# np.float64(1.8132948181795174)

# %% [markdown]
# Again: I have used a newcommand to redefine __\vec__ so that A vector now renders in bold (no "arrow over letter").
#
# Here is what this looks like in this cell: $\vec{v}$
#
# I also have a __newcommand__ that defines __\R__ to be the math black-board bold double struck R:
#
# It renders as follows: $\R$

# %%
np.sum(A)
# Out:
# np.float64(2.509256460951664)

# %% [markdown]
# Again: I have used a newcommand to redefine __\vec__ so that A vector now renders in bold (no "arrow over letter").
#
# Here is what this looks like in this cell: $\vec{v}$
#
# I also have a __newcommand__ that defines __\R__ to be the math black-board bold double struck R:
#
# It renders as follows: $\R$

# %%
A.copy() @ A
# Out:
# array([[1.06620358, 1.0310944 ],
#        [0.51126885, 0.54171722]])

# %% [markdown]
# Again: I have used a newcommand to redefine __\vec__ so that A vector now renders in bold (no "arrow over letter").
#
# Here is what this looks like in this cell: $\vec{v}$
#
# I also have a __newcommand__ that defines __\R__ to be the math black-board bold double struck R:
#
# It renders as follows: $\R$

# %%
np.triu(A.copy())
# Out:
# array([[0.78185794, 0.95781878],
#        [0.        , 0.29464465]])

# %% [markdown]
# Again: I have used a newcommand to redefine __\vec__ so that A vector now renders in bold (no "arrow over letter").
#
# Here is what this looks like in this cell: $\vec{v}$
#
# I also have a __newcommand__ that defines __\R__ to be the math black-board bold double struck R:
#
# It renders as follows: $\R$
#
# I also have a __newcommand__ that defines __\C__ to be the math black-board bold double struck C:
#
# It renders as follows: $\C$
